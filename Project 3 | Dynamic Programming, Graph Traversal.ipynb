# %% [markdown]
# \begin{flushleft}
# Raymond Hear (GWID:G26215348)\linebreak
# Design and Analysis of Algorithms (CSCI 6212)\linebreak
# Professor Amrinder Arora\linebreak
# 29 June 2021\linebreak
# \end{flushleft}

# %% [markdown]
# \begin{flushleft}
# If your GWID ends in 5..9, Fast Response k-Server Problem:
# http://www.notexponential.com/notes/projects/project-3/
# \end{flushleft}

# %% [markdown]
# ### Fast Response k-Server Problem
# > A series of client machines [1, 2, … n] are located along a linear network. The i-th client generates amount of traffic that is given by w[i]. You want to place k servers along the linear network that minimizes the total amount of traffic carried by the network. Total traffic is given by sum of each client’s individual traffic, multiplied by the distance (the number of hops) from the server. Provide a polynomial time algorithm to identify the optimal locations for k servers.<br>
# > Do not require the user to take any part in the input ("Input the graph, or even input the number of points or input size, etc.)

# %% [markdown]
# ## Key Implementation Characteristics

# %% [markdown]
# The goal of the k-servers problem is to put servers where the traffic load is the highest. To find where the traffic is the highest, we create a tally of the traffic between each client machine and track the sum in a variable `max_so_far`. This sum represents the longest continuous flow of traffic.
#
#
# The key implementation characteristics are as follows:
#
#
# - Client machines are arranged as a 1D array.
# - Client machines can generate negative traffic (i.e., act as hosts/consumers and are not always positive).
# - The distance between two client machines is the minimum traffic.
# - The total traffic of an array is found by summing the differences between contiguous client machines.
# - We will use a variable max_so_far to tally the sum of the subarray.

# %% [markdown]
# ## Numerical results for different input sizes (Chart that indicates time complexity.)

# %%
import numpy as np
from scipy.interpolate import BSpline, make_interp_spline
import seaborn as sns

# %%
x = np.array(input_size)
y = np.array(run_time)

x_new = np.linspace(start=x.min(), stop=x.max(), num=50)
a_BSpline = make_interp_spline(np.sort(x), np.sort(y))
y_new = a_BSpline(x_new)

sns.set_style("whitegrid")
sns.despine()
sns.lineplot(x=sorted(x, key=int), y=sorted(y, key=int), color="#0f4c81")
plt.xlabel("ELEMENTS")
plt.ylabel("RUNTIME (ns)")
plt.title("PLOT OF ARRAY LENGTH VS RUNTIME")

# %% [markdown]
# ![title](plot_time_complexity_sorted.png)

# %% [markdown]
# ## Algorithmic Programs

# %%
import matplotlib.pyplot as plt
from random import choice, randint, sample
from sys import maxsize
import time

# %%
def calculate_max_traffic(client_machines, size):

    # Initialise variables
    max_so_far = -maxsize - 1 # 2**63 - 1 on a 64-bit platform, equivalent to -inf
    max_ending_here = 0 # Max between 
    start, end = 0, 0 # Starting and ending indexes
    s = 0 # The beginning of the subarray

    # Iterate over the length of the given array beginning at index 0
    for i in range(size):

        # Find the traffic between two client machines
        max_ending_here += client_machines[i]
        
        # Compare the max traffic so far against the traffic between between two client machines
        # If traffic from a client machine is gt -inf, assign that value to the max traffic of the subarray
        if max_so_far < max_ending_here:
            max_so_far = max_ending_here
            start = s # Starting index
            end = i # Update the ending index
        
        # If the client machine produces negative values, restart the 
        if max_ending_here < 0:
            max_ending_here = 0
            s = i + 1
    
    # Return an array of the values:
    # - max traffic of the subarray; 
    # - starting index of the subarray; 
    # - ending index of the subarray; 
    # - print out of the subarray
    return {
        "maximum contiguous sum": max_so_far,
        "start index": start,
        "end index": end,
        "client machines": client_machines[start : end + 1],
    }

# %% [markdown]
# ## Driver program

# %%
# Track runtime and length of array for plotting
run_time = []
input_size = []

# Run this experiement 1,000 times
for _ in range(1_000):
    # Generate an array of random length (0 to 5M) and populate the array with integers ranging from -5M to 5M
    client_machines = sample(range(-5_999_999, 5_999_999), randint(0, 5_000_000))
    # Start the timer
    start_time = time.time_ns()
    # Call the function to find max traffic
    output = calculate_max_traffic(client_machines, len(client_machines))
    # Stop the timer
    end_time = time.time_ns()
    # Print the results of the run to console
    print(f'RUN {_} ===========================')
    print(f'> MAX TRAFFIC: {output["maximum contiguous sum"]:,d}')
    print(f'> START SERVER PLACEMENT AT INDEX: {output["start index"]:,d}')
    print(f'> END SERVER PLACEMENT ON INDEX: {output["end index"]:,d}')
    print(f'> NUMBER OF CLIENT MACHINES: {len(client_machines):,d}')
    # print(f'> ALL CLIENT MACHINES:\n{client_machines}')
    # print(f'> HIGHEST CONTIGUOUS TRAFFIC:\n{client_machines[output["start index"]:output["end index"]]}')
    print("\n")
    # Save the runtime and length of the array for plotting
    run_time.append(end_time - start_time)
    input_size.append(len(client_machines))

print(f'> RUNTIME (ns): {run_time}')
print(f'> ARRAY SIZE: {input_size}')
# Out:
# RUN 0 ===========================
# > MAX TRAFFIC: 7,641,175,493
# > START SERVER PLACEMENT AT INDEX: 446,015
# > END SERVER PLACEMENT ON INDEX: 2,717,696
# > NUMBER OF CLIENT MACHINES: 4,733,795
#
#
# RUN 1 ===========================
# > MAX TRAFFIC: 11,822,706,303
# > START SERVER PLACEMENT AT INDEX: 3,193,697
# > END SERVER PLACEMENT ON INDEX: 4,588,702
# > NUMBER OF CLIENT MACHINES: 4,728,475
#
#
# RUN 2 ===========================
# > MAX TRAFFIC: 10,736,259,127
# > START SERVER PLACEMENT AT INDEX: 1,620,863
# > END SERVER PLACEMENT ON INDEX: 4,101,906
# > NUMBER OF CLIENT MACHINES: 4,610,290
#
#
# RUN 3 ===========================
# > MAX TRAFFIC: 8,462,162,316
# > START SERVER PLACEMENT AT INDEX: 1,006,939
# > END SERVER PLACEMENT ON INDEX: 3,547,383
# > NUMBER OF CLIENT MACHINES: 4,039,756
#
#
# RUN 4 ===========================
# > MAX TRAFFIC: 5,052,166,213
# > START SERVER PLACEMENT AT INDEX: 2,851
# > END SERVER PLACEMENT ON INDEX: 949,790
# > NUMBER OF CLIENT MACHINES: 1,618,608
#
#
# RUN 5 ===========================
# > MAX TRAFFIC: 6,504,934,532
# > START SERVER PLACEMENT AT INDEX: 78,099
# > END SERVER PLACEMENT ON INDEX: 1,248,936
# > NUMBER OF CLIENT MACHINES: 1,463,973
#
#
# RUN 6 ===========================
# > MAX TRAFFIC: 10,377,986,696
# > START SERVER PLACEMENT AT INDEX: 289,615
# > END SERVER PLACEMENT ON INDEX: 1,588,038
# > NUMBER OF CLIENT MACHINES: 4,673,955
#
#
# RUN 7 ===========================
# > MAX TRAFFIC: 4,785,469,562
# > START SERVER PLACEMENT AT INDEX: 165,270
# > END SERVER PLACEMENT ON INDEX: 1,503,414
# > NUMBER OF CLIENT MACHINES: 2,483,655
#
#
# RUN 8 ===========================
# > MAX TRAFFIC: 4,864,414,924
# > START SERVER PLACEMENT AT INDEX: 51,542
# > END SERVER PLACEMENT ON INDEX: 664,548
# > NUMBER OF CLIENT MACHINES: 928,526
#
#
# RUN 9 ===========================
# > MAX TRAFFIC: 8,508,277,005
# > START SERVER PLACEMENT AT INDEX: 713,443
# > END SERVER PLACEMENT ON INDEX: 2,091,678
# > NUMBER OF CLIENT MACHINES: 3,629,946
#
#
# RUN 10 ===========================
# > MAX TRAFFIC: 6,717,207,088
# > START SERVER PLACEMENT AT INDEX: 1,497,135
# > END SERVER PLACEMENT ON INDEX: 1,967,143
# > NUMBER OF CLIENT MACHINES: 3,037,567
#
#
# RUN 11 ===========================
# > MAX TRAFFIC: 9,233,381,717
# > START SERVER PLACEMENT AT INDEX: 501,352
# > END SERVER PLACEMENT ON INDEX: 2,886,186
# > NUMBER OF CLIENT MACHINES: 2,991,875
#
#
# RUN 12 ===========================
# > MAX TRAFFIC: 12,590,257,772
# > START SERVER PLACEMENT AT INDEX: 567,003
# > END SERVER PLACEMENT ON INDEX: 3,525,013
# > NUMBER OF CLIENT MACHINES: 3,806,467
#
#
# RUN 13 ===========================
# > MAX TRAFFIC: 8,581,337,815
# > START SERVER PLACEMENT AT INDEX: 64,132
# > END SERVER PLACEMENT ON INDEX: 1,901,694
# > NUMBER OF CLIENT MACHINES: 2,068,414
#
#
# RUN 14 ===========================
# > MAX TRAFFIC: 10,761,250,256
# > START SERVER PLACEMENT AT INDEX: 189,008
# > END SERVER PLACEMENT ON INDEX: 1,756,984
# > NUMBER OF CLIENT MACHINES: 2,130,024
#
#
# RUN 15 ===========================
# > MAX TRAFFIC: 3,572,916,611
# > START SERVER PLACEMENT AT INDEX: 618,834
# > END SERVER PLACEMENT ON INDEX: 1,075,397
# > NUMBER OF CLIENT MACHINES: 1,664,315
#
#
# RUN 16 ===========================
# > MAX TRAFFIC: 8,777,516,974
# > START SERVER PLACEMENT AT INDEX: 1,472,119
# > END SERVER PLACEMENT ON INDEX: 2,407,830
# > NUMBER OF CLIENT MACHINES: 2,427,992
#
#
# RUN 17 ===========================
# > MAX TRAFFIC: 9,016,698,056
# > START SERVER PLACEMENT AT INDEX: 2,259,621
# > END SERVER PLACEMENT ON INDEX: 3,585,899
# > NUMBER OF CLIENT MACHINES: 3,674,165
#
#
# RUN 18 ===========================
# > MAX TRAFFIC: 8,556,654,832
# > START SERVER PLACEMENT AT INDEX: 422,550
# > END SERVER PLACEMENT ON INDEX: 1,281,342
# > NUMBER OF CLIENT MACHINES: 3,098,571
#
#
# RUN 19 ===========================
# > MAX TRAFFIC: 5,471,080,801
# > START SERVER PLACEMENT AT INDEX: 27,852
# > END SERVER PLACEMENT ON INDEX: 841,847
# > NUMBER OF CLIENT MACHINES: 1,875,904
#
#
# RUN 20 ===========================
# > MAX TRAFFIC: 7,731,337,447
# > START SERVER PLACEMENT AT INDEX: 1,920,793
# > END SERVER PLACEMENT ON INDEX: 2,540,149
# > NUMBER OF CLIENT MACHINES: 2,776,173
#
#
# RUN 21 ===========================
# > MAX TRAFFIC: 8,190,308,959
# > START SERVER PLACEMENT AT INDEX: 45,135
# > END SERVER PLACEMENT ON INDEX: 1,240,218
# > NUMBER OF CLIENT MACHINES: 3,132,661
#
#
# RUN 22 ===========================
# > MAX TRAFFIC: 9,852,039,606
# > START SERVER PLACEMENT AT INDEX: 5,048
# > END SERVER PLACEMENT ON INDEX: 2,009,322
# > NUMBER OF CLIENT MACHINES: 2,068,073
#
#
# RUN 23 ===========================
# > MAX TRAFFIC: 7,299,605,333
# > START SERVER PLACEMENT AT INDEX: 2,845,149
# > END SERVER PLACEMENT ON INDEX: 4,072,872
# > NUMBER OF CLIENT MACHINES: 4,499,628
#
#
# RUN 24 ===========================
# > MAX TRAFFIC: 1,226,860,919
# > START SERVER PLACEMENT AT INDEX: 224,123
# > END SERVER PLACEMENT ON INDEX: 263,371
# > NUMBER OF CLIENT MACHINES: 912,955
#
#
# RUN 25 ===========================
# > MAX TRAFFIC: 6,831,003,742
# > START SERVER PLACEMENT AT INDEX: 672,366
# > END SERVER PLACEMENT ON INDEX: 1,934,605
# > NUMBER OF CLIENT MACHINES: 4,297,917
#
#
# RUN 26 ===========================
# > MAX TRAFFIC: 10,639,212,932
# > START SERVER PLACEMENT AT INDEX: 1,025,826
# > END SERVER PLACEMENT ON INDEX: 4,335,523
# > NUMBER OF CLIENT MACHINES: 4,892,395
#
#
# RUN 27 ===========================
# > MAX TRAFFIC: 7,777,833,180
# > START SERVER PLACEMENT AT INDEX: 91,486
# > END SERVER PLACEMENT ON INDEX: 701,854
# > NUMBER OF CLIENT MACHINES: 714,172
#
#
# RUN 28 ===========================
# > MAX TRAFFIC: 6,242,603,788
# > START SERVER PLACEMENT AT INDEX: 1,010,902
# > END SERVER PLACEMENT ON INDEX: 2,248,380
# > NUMBER OF CLIENT MACHINES: 2,413,020
#
#
# RUN 29 ===========================
# > MAX TRAFFIC: 8,253,824,530
# > START SERVER PLACEMENT AT INDEX: 374,995
# > END SERVER PLACEMENT ON INDEX: 3,090,712
# > NUMBER OF CLIENT MACHINES: 4,100,996
#
#
# RUN 30 ===========================
# > MAX TRAFFIC: 11,262,397,791
# > START SERVER PLACEMENT AT INDEX: 427,559
# > END SERVER PLACEMENT ON INDEX: 3,326,473
# > NUMBER OF CLIENT MACHINES: 3,662,299
#
#
# RUN 31 ===========================
# > MAX TRAFFIC: 2,388,476,610
# > START SERVER PLACEMENT AT INDEX: 62,245
# > END SERVER PLACEMENT ON INDEX: 191,744
# > NUMBER OF CLIENT MACHINES: 1,817,357
#
#
# RUN 32 ===========================
# > MAX TRAFFIC: 6,944,739,864
# > START SERVER PLACEMENT AT INDEX: 2,442,373
# > END SERVER PLACEMENT ON INDEX: 3,239,926
# > NUMBER OF CLIENT MACHINES: 3,748,853
#
#
# RUN 33 ===========================
# > MAX TRAFFIC: 4,550,323,873
# > START SERVER PLACEMENT AT INDEX: 927,708
# > END SERVER PLACEMENT ON INDEX: 1,121,855
# > NUMBER OF CLIENT MACHINES: 1,142,064
#
#
# RUN 34 ===========================
# > MAX TRAFFIC: 10,195,030,951
# > START SERVER PLACEMENT AT INDEX: 1,920,606
# > END SERVER PLACEMENT ON INDEX: 3,369,406
# > NUMBER OF CLIENT MACHINES: 3,731,521
#
#
# RUN 35 ===========================
# > MAX TRAFFIC: 8,872,557,658
# > START SERVER PLACEMENT AT INDEX: 2,156,416
# > END SERVER PLACEMENT ON INDEX: 2,998,133
# > NUMBER OF CLIENT MACHINES: 4,854,641
#
#
# RUN 36 ===========================
# > MAX TRAFFIC: 4,281,304,003
# > START SERVER PLACEMENT AT INDEX: 62,387
# > END SERVER PLACEMENT ON INDEX: 372,123
# > NUMBER OF CLIENT MACHINES: 1,312,344
#
#
# RUN 37 ===========================
# > MAX TRAFFIC: 3,679,402,034
# > START SERVER PLACEMENT AT INDEX: 633,713
# > END SERVER PLACEMENT ON INDEX: 783,648
# > NUMBER OF CLIENT MACHINES: 871,082
#
#
# RUN 38 ===========================
# > MAX TRAFFIC: 4,815,812,793
# > START SERVER PLACEMENT AT INDEX: 3,252,306
# > END SERVER PLACEMENT ON INDEX: 3,782,572
# > NUMBER OF CLIENT MACHINES: 3,950,346
#
#
# RUN 39 ===========================
# > MAX TRAFFIC: 7,420,987,712
# > START SERVER PLACEMENT AT INDEX: 1,974,159
# > END SERVER PLACEMENT ON INDEX: 3,741,277
# > NUMBER OF CLIENT MACHINES: 4,758,238
#
#
# RUN 40 ===========================
# > MAX TRAFFIC: 7,522,692,825
# > START SERVER PLACEMENT AT INDEX: 680,504
# > END SERVER PLACEMENT ON INDEX: 1,283,173
# > NUMBER OF CLIENT MACHINES: 1,339,241
#
#
# RUN 41 ===========================
# > MAX TRAFFIC: 8,275,295,951
# > START SERVER PLACEMENT AT INDEX: 1,855,729
# > END SERVER PLACEMENT ON INDEX: 3,359,007
# > NUMBER OF CLIENT MACHINES: 4,061,272
#
#
# RUN 42 ===========================
# > MAX TRAFFIC: 5,133,847,403
# > START SERVER PLACEMENT AT INDEX: 299,118
# > END SERVER PLACEMENT ON INDEX: 1,082,969
# > NUMBER OF CLIENT MACHINES: 1,286,973
# RUN 43 ===========================
# > MAX TRAFFIC: 5,542,693,187
# > START SERVER PLACEMENT AT INDEX: 245,517
# > END SERVER PLACEMENT ON INDEX: 672,104
# > NUMBER OF CLIENT MACHINES: 941,220
#
#
# RUN 44 ===========================
# > MAX TRAFFIC: 6,600,167,116
# > START SERVER PLACEMENT AT INDEX: 888,867
# > END SERVER PLACEMENT ON INDEX: 2,670,904
# > NUMBER OF CLIENT MACHINES: 3,246,501
#
#
# RUN 45 ===========================
# > MAX TRAFFIC: 4,725,029,070
# > START SERVER PLACEMENT AT INDEX: 78,509
# > END SERVER PLACEMENT ON INDEX: 1,225,905
# > NUMBER OF CLIENT MACHINES: 2,574,581
#
#
# RUN 46 ===========================
# > MAX TRAFFIC: 8,897,443,335
# > START SERVER PLACEMENT AT INDEX: 1,066,735
# > END SERVER PLACEMENT ON INDEX: 2,664,502
# > NUMBER OF CLIENT MACHINES: 2,902,876
#
#
# RUN 47 ===========================
# > MAX TRAFFIC: 4,251,334,796
# > START SERVER PLACEMENT AT INDEX: 1,143,356
# > END SERVER PLACEMENT ON INDEX: 1,503,341
# > NUMBER OF CLIENT MACHINES: 2,137,005
#
#
# RUN 48 ===========================
# > MAX TRAFFIC: 3,334,365,069
# > START SERVER PLACEMENT AT INDEX: 164,234
# > END SERVER PLACEMENT ON INDEX: 375,594
# > NUMBER OF CLIENT MACHINES: 1,374,860
#
#
# RUN 49 ===========================
# > MAX TRAFFIC: 7,225,763,562
# > START SERVER PLACEMENT AT INDEX: 2,110
# > END SERVER PLACEMENT ON INDEX: 1,007,539
# > NUMBER OF CLIENT MACHINES: 3,630,030
#
#
# RUN 50 ===========================
# > MAX TRAFFIC: 4,239,497,018
# > START SERVER PLACEMENT AT INDEX: 501
# > END SERVER PLACEMENT ON INDEX: 242,206
# > NUMBER OF CLIENT MACHINES: 902,592
#
#
# RUN 51 ===========================
# > MAX TRAFFIC: 3,066,163,274
# > START SERVER PLACEMENT AT INDEX: 2,966
# > END SERVER PLACEMENT ON INDEX: 93,144
# > NUMBER OF CLIENT MACHINES: 304,542
#
#
# RUN 52 ===========================
# > MAX TRAFFIC: 4,903,539,765
# > START SERVER PLACEMENT AT INDEX: 73,704
# > END SERVER PLACEMENT ON INDEX: 562,154
# > NUMBER OF CLIENT MACHINES: 2,096,820
#
#
# RUN 53 ===========================
# > MAX TRAFFIC: 900,809,044
# > START SERVER PLACEMENT AT INDEX: 6,016
# > END SERVER PLACEMENT ON INDEX: 25,506
# > NUMBER OF CLIENT MACHINES: 173,519
#
#
# RUN 54 ===========================
# > MAX TRAFFIC: 6,086,385,270
# > START SERVER PLACEMENT AT INDEX: 90,869
# > END SERVER PLACEMENT ON INDEX: 630,073
# > NUMBER OF CLIENT MACHINES: 2,429,160
#
#
# RUN 55 ===========================
# > MAX TRAFFIC: 7,628,910,064
# > START SERVER PLACEMENT AT INDEX: 2,827,899
# > END SERVER PLACEMENT ON INDEX: 4,047,886
# > NUMBER OF CLIENT MACHINES: 4,081,652
#
#
# RUN 56 ===========================
# > MAX TRAFFIC: 7,756,321,653
# > START SERVER PLACEMENT AT INDEX: 10,427
# > END SERVER PLACEMENT ON INDEX: 773,463
# > NUMBER OF CLIENT MACHINES: 2,416,125
#
#
# RUN 57 ===========================
# > MAX TRAFFIC: 12,869,166,364
# > START SERVER PLACEMENT AT INDEX: 1,378,657
# > END SERVER PLACEMENT ON INDEX: 4,103,029
# > NUMBER OF CLIENT MACHINES: 4,156,564
#
#
# RUN 58 ===========================
# > MAX TRAFFIC: 4,616,761,712
# > START SERVER PLACEMENT AT INDEX: 751,846
# > END SERVER PLACEMENT ON INDEX: 1,454,193
# > NUMBER OF CLIENT MACHINES: 3,438,161
#
#
# RUN 59 ===========================
# > MAX TRAFFIC: 7,517,038,120
# > START SERVER PLACEMENT AT INDEX: 440,231
# > END SERVER PLACEMENT ON INDEX: 1,749,517
# > NUMBER OF CLIENT MACHINES: 1,752,673
#
#
# RUN 60 ===========================
# > MAX TRAFFIC: 4,347,982,112
# > START SERVER PLACEMENT AT INDEX: 253,053
# > END SERVER PLACEMENT ON INDEX: 607,765
# > NUMBER OF CLIENT MACHINES: 808,064
#
#
# RUN 61 ===========================
# > MAX TRAFFIC: 6,334,781,494
# > START SERVER PLACEMENT AT INDEX: 1,863,513
# > END SERVER PLACEMENT ON INDEX: 3,028,613
# > NUMBER OF CLIENT MACHINES: 4,158,354
#
#
# RUN 62 ===========================
# > MAX TRAFFIC: 3,687,597,819
# > START SERVER PLACEMENT AT INDEX: 577,839
# > END SERVER PLACEMENT ON INDEX: 1,299,099
# > NUMBER OF CLIENT MACHINES: 3,243,385
#
#
# RUN 63 ===========================
# > MAX TRAFFIC: 5,943,017,065
# > START SERVER PLACEMENT AT INDEX: 676,045
# > END SERVER PLACEMENT ON INDEX: 1,073,480
# > NUMBER OF CLIENT MACHINES: 1,360,429
#
#
# RUN 64 ===========================
# > MAX TRAFFIC: 7,130,655,742
# > START SERVER PLACEMENT AT INDEX: 440,424
# > END SERVER PLACEMENT ON INDEX: 2,246,023
# > NUMBER OF CLIENT MACHINES: 3,172,626
#
#
# RUN 65 ===========================
# > MAX TRAFFIC: 4,459,841,332
# > START SERVER PLACEMENT AT INDEX: 662,332
# > END SERVER PLACEMENT ON INDEX: 1,239,326
# > NUMBER OF CLIENT MACHINES: 1,246,929
#
#
# RUN 66 ===========================
# > MAX TRAFFIC: 4,491,797,919
# > START SERVER PLACEMENT AT INDEX: 716,594
# > END SERVER PLACEMENT ON INDEX: 1,592,020
# > NUMBER OF CLIENT MACHINES: 3,821,497
#
#
# RUN 67 ===========================
# > MAX TRAFFIC: 2,088,637,791
# > START SERVER PLACEMENT AT INDEX: 8,734
# > END SERVER PLACEMENT ON INDEX: 74,942
# > NUMBER OF CLIENT MACHINES: 85,139
#
#
# RUN 68 ===========================
# > MAX TRAFFIC: 3,690,355,629
# > START SERVER PLACEMENT AT INDEX: 44,631
# > END SERVER PLACEMENT ON INDEX: 496,783
# > NUMBER OF CLIENT MACHINES: 982,793
#
#
# RUN 69 ===========================
# > MAX TRAFFIC: 9,121,692,826
# > START SERVER PLACEMENT AT INDEX: 1,253,334
# > END SERVER PLACEMENT ON INDEX: 3,232,534
# > NUMBER OF CLIENT MACHINES: 3,446,616
#
#
# RUN 70 ===========================
# > MAX TRAFFIC: 9,619,450,040
# > START SERVER PLACEMENT AT INDEX: 663,018
# > END SERVER PLACEMENT ON INDEX: 3,237,299
# > NUMBER OF CLIENT MACHINES: 4,153,501
#
#
# RUN 71 ===========================
# > MAX TRAFFIC: 8,320,295,279
# > START SERVER PLACEMENT AT INDEX: 932,620
# > END SERVER PLACEMENT ON INDEX: 2,388,241
# > NUMBER OF CLIENT MACHINES: 3,595,180
#
#
# RUN 72 ===========================
# > MAX TRAFFIC: 7,125,106,680
# > START SERVER PLACEMENT AT INDEX: 668
# > END SERVER PLACEMENT ON INDEX: 1,187,834
# > NUMBER OF CLIENT MACHINES: 3,807,318
#
#
# RUN 73 ===========================
# > MAX TRAFFIC: 7,946,341,369
# > START SERVER PLACEMENT AT INDEX: 226,728
# > END SERVER PLACEMENT ON INDEX: 872,632
# > NUMBER OF CLIENT MACHINES: 2,586,419
#
#
# RUN 74 ===========================
# > MAX TRAFFIC: 4,140,207,694
# > START SERVER PLACEMENT AT INDEX: 7,810
# > END SERVER PLACEMENT ON INDEX: 405,293
# > NUMBER OF CLIENT MACHINES: 1,111,664
#
#
# RUN 75 ===========================
# > MAX TRAFFIC: 12,870,361,313
# > START SERVER PLACEMENT AT INDEX: 769,744
# > END SERVER PLACEMENT ON INDEX: 3,633,331
# > NUMBER OF CLIENT MACHINES: 4,555,047
#
#
# RUN 76 ===========================
# > MAX TRAFFIC: 16,248,511,595
# > START SERVER PLACEMENT AT INDEX: 137,683
# > END SERVER PLACEMENT ON INDEX: 4,182,451
# > NUMBER OF CLIENT MACHINES: 4,320,839
#
#
# RUN 77 ===========================
# > MAX TRAFFIC: 3,185,603,745
# > START SERVER PLACEMENT AT INDEX: 394,559
# > END SERVER PLACEMENT ON INDEX: 771,716
# > NUMBER OF CLIENT MACHINES: 1,885,640
#
#
# RUN 78 ===========================
# > MAX TRAFFIC: 9,580,973,355
# > START SERVER PLACEMENT AT INDEX: 1,278,005
# > END SERVER PLACEMENT ON INDEX: 4,018,583
# > NUMBER OF CLIENT MACHINES: 4,991,526
#
#
# RUN 79 ===========================
# > MAX TRAFFIC: 5,474,680,289
# > START SERVER PLACEMENT AT INDEX: 249,111
# > END SERVER PLACEMENT ON INDEX: 683,109
# > NUMBER OF CLIENT MACHINES: 2,347,114
#
#
# RUN 80 ===========================
# > MAX TRAFFIC: 3,158,482,792
# > START SERVER PLACEMENT AT INDEX: 1,869,391
# > END SERVER PLACEMENT ON INDEX: 2,413,423
# > NUMBER OF CLIENT MACHINES: 2,464,845
#
#
# RUN 81 ===========================
# > MAX TRAFFIC: 3,840,276,004
# > START SERVER PLACEMENT AT INDEX: 1,170,716
# > END SERVER PLACEMENT ON INDEX: 1,599,175
# > NUMBER OF CLIENT MACHINES: 1,773,315
#
#
# RUN 82 ===========================
# > MAX TRAFFIC: 9,241,942,332
# > START SERVER PLACEMENT AT INDEX: 2,543,658
# > END SERVER PLACEMENT ON INDEX: 4,564,178
# > NUMBER OF CLIENT MACHINES: 4,651,303
#
#
# RUN 83 ===========================
# > MAX TRAFFIC: 1,301,733,986
# > START SERVER PLACEMENT AT INDEX: 4,937
# > END SERVER PLACEMENT ON INDEX: 33,396
# > NUMBER OF CLIENT MACHINES: 46,216
#
#
# RUN 84 ===========================
# > MAX TRAFFIC: 9,188,667,482
# > START SERVER PLACEMENT AT INDEX: 4,579
# > END SERVER PLACEMENT ON INDEX: 1,709,274
# > NUMBER OF CLIENT MACHINES: 3,153,203
#
#
# RUN 85 ===========================
# > MAX TRAFFIC: 11,676,838,325
# > START SERVER PLACEMENT AT INDEX: 856,228
# > END SERVER PLACEMENT ON INDEX: 3,237,710
# > NUMBER OF CLIENT MACHINES: 3,253,108
#
#
# RUN 86 ===========================
# > MAX TRAFFIC: 5,370,605,911
# > START SERVER PLACEMENT AT INDEX: 456,029
# > END SERVER PLACEMENT ON INDEX: 950,199
# > NUMBER OF CLIENT MACHINES: 1,210,062
# RUN 87 ===========================
# > MAX TRAFFIC: 2,087,950,730
# > START SERVER PLACEMENT AT INDEX: 82,064
# > END SERVER PLACEMENT ON INDEX: 316,730
# > NUMBER OF CLIENT MACHINES: 410,426
#
#
# RUN 88 ===========================
# > MAX TRAFFIC: 10,389,649,992
# > START SERVER PLACEMENT AT INDEX: 2,292,587
# > END SERVER PLACEMENT ON INDEX: 3,842,080
# > NUMBER OF CLIENT MACHINES: 4,736,987
#
#
# RUN 89 ===========================
# > MAX TRAFFIC: 2,966,869,568
# > START SERVER PLACEMENT AT INDEX: 496,518
# > END SERVER PLACEMENT ON INDEX: 656,565
# > NUMBER OF CLIENT MACHINES: 709,882
#
#
# RUN 90 ===========================
# > MAX TRAFFIC: 4,360,127,633
# > START SERVER PLACEMENT AT INDEX: 1,406,678
# > END SERVER PLACEMENT ON INDEX: 1,750,179
# > NUMBER OF CLIENT MACHINES: 4,231,875
#
#
# RUN 91 ===========================
# > MAX TRAFFIC: 13,732,621,251
# > START SERVER PLACEMENT AT INDEX: 37,169
# > END SERVER PLACEMENT ON INDEX: 2,295,781
# > NUMBER OF CLIENT MACHINES: 4,885,212
#
#
# RUN 92 ===========================
# > MAX TRAFFIC: 7,919,531,896
# > START SERVER PLACEMENT AT INDEX: 444,091
# > END SERVER PLACEMENT ON INDEX: 1,492,388
# > NUMBER OF CLIENT MACHINES: 4,580,997
#
#
# RUN 93 ===========================
# > MAX TRAFFIC: 15,517,712,414
# > START SERVER PLACEMENT AT INDEX: 1,147,827
# > END SERVER PLACEMENT ON INDEX: 3,362,850
# > NUMBER OF CLIENT MACHINES: 4,505,454
#
#
# RUN 94 ===========================
# > MAX TRAFFIC: 1,722,091,331
# > START SERVER PLACEMENT AT INDEX: 287
# > END SERVER PLACEMENT ON INDEX: 53,625
# > NUMBER OF CLIENT MACHINES: 123,140
#
#
# RUN 95 ===========================
# > MAX TRAFFIC: 3,486,100,032
# > START SERVER PLACEMENT AT INDEX: 86,940
# > END SERVER PLACEMENT ON INDEX: 599,222
# > NUMBER OF CLIENT MACHINES: 1,065,292
#
#
# RUN 96 ===========================
# > MAX TRAFFIC: 2,816,749,340
# > START SERVER PLACEMENT AT INDEX: 235,969
# > END SERVER PLACEMENT ON INDEX: 435,316
# > NUMBER OF CLIENT MACHINES: 463,331
#
#
# RUN 97 ===========================
# > MAX TRAFFIC: 5,646,807,123
# > START SERVER PLACEMENT AT INDEX: 577,509
# > END SERVER PLACEMENT ON INDEX: 1,497,814
# > NUMBER OF CLIENT MACHINES: 3,619,809
#
#
# RUN 98 ===========================
# > MAX TRAFFIC: 7,351,986,320
# > START SERVER PLACEMENT AT INDEX: 1,836,506
# > END SERVER PLACEMENT ON INDEX: 2,465,628
# > NUMBER OF CLIENT MACHINES: 4,773,495
#
#
# RUN 99 ===========================
# > MAX TRAFFIC: 13,033,592,378
# > START SERVER PLACEMENT AT INDEX: 934,128
# > END SERVER PLACEMENT ON INDEX: 2,839,003
# > NUMBER OF CLIENT MACHINES: 3,196,897
#
#
# RUN 100 ===========================
# > MAX TRAFFIC: 5,833,740,870
# > START SERVER PLACEMENT AT INDEX: 1,192,306
# > END SERVER PLACEMENT ON INDEX: 2,322,036
# > NUMBER OF CLIENT MACHINES: 2,340,696
#
#
# RUN 101 ===========================
# > MAX TRAFFIC: 9,906,731,725
# > START SERVER PLACEMENT AT INDEX: 736,494
# > END SERVER PLACEMENT ON INDEX: 2,436,232
# > NUMBER OF CLIENT MACHINES: 4,656,145
#
#
# RUN 102 ===========================
# > MAX TRAFFIC: 15,534,445,388
# > START SERVER PLACEMENT AT INDEX: 68,962
# > END SERVER PLACEMENT ON INDEX: 3,182,400
# > NUMBER OF CLIENT MACHINES: 3,794,358
#
#
# RUN 103 ===========================
# > MAX TRAFFIC: 5,844,763,838
# > START SERVER PLACEMENT AT INDEX: 1,343,663
# > END SERVER PLACEMENT ON INDEX: 2,847,587
# > NUMBER OF CLIENT MACHINES: 2,946,134
#
#
# RUN 104 ===========================
# > MAX TRAFFIC: 5,644,932,047
# > START SERVER PLACEMENT AT INDEX: 335,557
# > END SERVER PLACEMENT ON INDEX: 984,294
# > NUMBER OF CLIENT MACHINES: 1,547,851
#
#
# RUN 105 ===========================
# > MAX TRAFFIC: 8,679,936,523
# > START SERVER PLACEMENT AT INDEX: 446,812
# > END SERVER PLACEMENT ON INDEX: 2,118,546
# > NUMBER OF CLIENT MACHINES: 4,273,603
#
#
# RUN 106 ===========================
# > MAX TRAFFIC: 8,345,873,259
# > START SERVER PLACEMENT AT INDEX: 76,433
# > END SERVER PLACEMENT ON INDEX: 2,408,369
# > NUMBER OF CLIENT MACHINES: 2,432,024
#
#
# RUN 107 ===========================
# > MAX TRAFFIC: 11,435,998,455
# > START SERVER PLACEMENT AT INDEX: 1,866,347
# > END SERVER PLACEMENT ON INDEX: 4,594,091
# > NUMBER OF CLIENT MACHINES: 4,594,744
#
#
# RUN 108 ===========================
# > MAX TRAFFIC: 11,381,684,926
# > START SERVER PLACEMENT AT INDEX: 184,064
# > END SERVER PLACEMENT ON INDEX: 2,548,045
# > NUMBER OF CLIENT MACHINES: 2,697,764
#
#
# RUN 109 ===========================
# > MAX TRAFFIC: 2,606,927,601
# > START SERVER PLACEMENT AT INDEX: 541,992
# > END SERVER PLACEMENT ON INDEX: 758,927
# > NUMBER OF CLIENT MACHINES: 1,066,198
#
#
# RUN 110 ===========================
# > MAX TRAFFIC: 12,575,901,856
# > START SERVER PLACEMENT AT INDEX: 445,141
# > END SERVER PLACEMENT ON INDEX: 2,699,617
# > NUMBER OF CLIENT MACHINES: 3,445,610
#
#
# RUN 111 ===========================
# > MAX TRAFFIC: 2,837,228,790
# > START SERVER PLACEMENT AT INDEX: 126,797
# > END SERVER PLACEMENT ON INDEX: 187,726
# > NUMBER OF CLIENT MACHINES: 1,014,678
#
#
# RUN 112 ===========================
# > MAX TRAFFIC: 5,324,681,797
# > START SERVER PLACEMENT AT INDEX: 400,227
# > END SERVER PLACEMENT ON INDEX: 790,812
# > NUMBER OF CLIENT MACHINES: 804,879
#
#
# RUN 113 ===========================
# > MAX TRAFFIC: 7,815,377,118
# > START SERVER PLACEMENT AT INDEX: 258,195
# > END SERVER PLACEMENT ON INDEX: 2,029,563
# > NUMBER OF CLIENT MACHINES: 2,456,892
#
#
# RUN 114 ===========================
# > MAX TRAFFIC: 8,503,584,813
# > START SERVER PLACEMENT AT INDEX: 147,504
# > END SERVER PLACEMENT ON INDEX: 1,663,016
# > NUMBER OF CLIENT MACHINES: 1,692,520
#
#
# RUN 115 ===========================
# > MAX TRAFFIC: 4,095,628,738
# > START SERVER PLACEMENT AT INDEX: 2,701,451
# > END SERVER PLACEMENT ON INDEX: 2,936,664
# > NUMBER OF CLIENT MACHINES: 2,942,920
#
#
# RUN 116 ===========================
# > MAX TRAFFIC: 9,125,185,637
# > START SERVER PLACEMENT AT INDEX: 195,431
# > END SERVER PLACEMENT ON INDEX: 2,630,940
# > NUMBER OF CLIENT MACHINES: 2,633,693
#
#
# RUN 117 ===========================
# > MAX TRAFFIC: 5,307,945,939
# > START SERVER PLACEMENT AT INDEX: 924,756
# > END SERVER PLACEMENT ON INDEX: 1,651,500
# > NUMBER OF CLIENT MACHINES: 2,474,377
#
#
# RUN 118 ===========================
# > MAX TRAFFIC: 12,855,163,400
# > START SERVER PLACEMENT AT INDEX: 1,207,069
# > END SERVER PLACEMENT ON INDEX: 3,225,702
# > NUMBER OF CLIENT MACHINES: 4,588,615
#
#
# RUN 119 ===========================
# > MAX TRAFFIC: 2,736,127,440
# > START SERVER PLACEMENT AT INDEX: 2,365,181
# > END SERVER PLACEMENT ON INDEX: 2,497,035
# > NUMBER OF CLIENT MACHINES: 2,757,963
#
#
# RUN 120 ===========================
# > MAX TRAFFIC: 3,713,464,362
# > START SERVER PLACEMENT AT INDEX: 7,561
# > END SERVER PLACEMENT ON INDEX: 365,986
# > NUMBER OF CLIENT MACHINES: 1,081,114
#
#
# RUN 121 ===========================
# > MAX TRAFFIC: 6,490,909,973
# > START SERVER PLACEMENT AT INDEX: 2,512,284
# > END SERVER PLACEMENT ON INDEX: 4,313,375
# > NUMBER OF CLIENT MACHINES: 4,314,038
#
#
# RUN 122 ===========================
# > MAX TRAFFIC: 3,284,312,462
# > START SERVER PLACEMENT AT INDEX: 1,179,049
# > END SERVER PLACEMENT ON INDEX: 1,417,409
# > NUMBER OF CLIENT MACHINES: 1,433,048
#
#
# RUN 123 ===========================
# > MAX TRAFFIC: 5,631,287,214
# > START SERVER PLACEMENT AT INDEX: 2,075,782
# > END SERVER PLACEMENT ON INDEX: 2,759,559
# > NUMBER OF CLIENT MACHINES: 3,179,096
#
#
# RUN 124 ===========================
# > MAX TRAFFIC: 4,481,796,463
# > START SERVER PLACEMENT AT INDEX: 240,153
# > END SERVER PLACEMENT ON INDEX: 543,258
# > NUMBER OF CLIENT MACHINES: 2,784,437
#
#
# RUN 125 ===========================
# > MAX TRAFFIC: 5,671,378,750
# > START SERVER PLACEMENT AT INDEX: 551,432
# > END SERVER PLACEMENT ON INDEX: 899,048
# > NUMBER OF CLIENT MACHINES: 4,446,018
#
#
# RUN 126 ===========================
# > MAX TRAFFIC: 3,474,420,049
# > START SERVER PLACEMENT AT INDEX: 564,149
# > END SERVER PLACEMENT ON INDEX: 1,012,403
# > NUMBER OF CLIENT MACHINES: 1,865,971
#
#
# RUN 127 ===========================
# > MAX TRAFFIC: 5,460,691,513
# > START SERVER PLACEMENT AT INDEX: 68,316
# > END SERVER PLACEMENT ON INDEX: 1,407,621
# > NUMBER OF CLIENT MACHINES: 1,981,216
#
#
# RUN 128 ===========================
# > MAX TRAFFIC: 5,695,937,017
# > START SERVER PLACEMENT AT INDEX: 2,776,820
# > END SERVER PLACEMENT ON INDEX: 4,304,876
# > NUMBER OF CLIENT MACHINES: 4,781,098
#
#
# RUN 129 ===========================
# > MAX TRAFFIC: 3,590,042,367
# > START SERVER PLACEMENT AT INDEX: 854,741
# > END SERVER PLACEMENT ON INDEX: 1,183,361
# > NUMBER OF CLIENT MACHINES: 1,185,039
# RUN 130 ===========================
# > MAX TRAFFIC: 7,213,209,301
# > START SERVER PLACEMENT AT INDEX: 326,951
# > END SERVER PLACEMENT ON INDEX: 2,879,382
# > NUMBER OF CLIENT MACHINES: 3,083,129
#
#
# RUN 131 ===========================
# > MAX TRAFFIC: 781,481,386
# > START SERVER PLACEMENT AT INDEX: 12,501
# > END SERVER PLACEMENT ON INDEX: 17,008
# > NUMBER OF CLIENT MACHINES: 52,566
#
#
# RUN 132 ===========================
# > MAX TRAFFIC: 1,291,984,489
# > START SERVER PLACEMENT AT INDEX: 489,177
# > END SERVER PLACEMENT ON INDEX: 591,451
# > NUMBER OF CLIENT MACHINES: 615,884
#
#
# RUN 133 ===========================
# > MAX TRAFFIC: 6,710,444,387
# > START SERVER PLACEMENT AT INDEX: 753,350
# > END SERVER PLACEMENT ON INDEX: 2,870,530
# > NUMBER OF CLIENT MACHINES: 3,841,442
#
#
# RUN 134 ===========================
# > MAX TRAFFIC: 11,214,562,303
# > START SERVER PLACEMENT AT INDEX: 611,280
# > END SERVER PLACEMENT ON INDEX: 4,128,358
# > NUMBER OF CLIENT MACHINES: 4,786,658
#
#
# RUN 135 ===========================
# > MAX TRAFFIC: 9,926,821,233
# > START SERVER PLACEMENT AT INDEX: 270,562
# > END SERVER PLACEMENT ON INDEX: 3,373,312
# > NUMBER OF CLIENT MACHINES: 3,504,124
#
#
# RUN 136 ===========================
# > MAX TRAFFIC: 2,770,051,025
# > START SERVER PLACEMENT AT INDEX: 1,641
# > END SERVER PLACEMENT ON INDEX: 75,806
# > NUMBER OF CLIENT MACHINES: 633,411
#
#
# RUN 137 ===========================
# > MAX TRAFFIC: 10,371,613,375
# > START SERVER PLACEMENT AT INDEX: 177
# > END SERVER PLACEMENT ON INDEX: 1,488,313
# > NUMBER OF CLIENT MACHINES: 3,328,876
#
#
# RUN 138 ===========================
# > MAX TRAFFIC: 7,666,800,814
# > START SERVER PLACEMENT AT INDEX: 1,838
# > END SERVER PLACEMENT ON INDEX: 1,205,728
# > NUMBER OF CLIENT MACHINES: 3,221,176
#
#
# RUN 139 ===========================
# > MAX TRAFFIC: 5,581,554,799
# > START SERVER PLACEMENT AT INDEX: 1,946,074
# > END SERVER PLACEMENT ON INDEX: 2,643,661
# > NUMBER OF CLIENT MACHINES: 3,570,347
#
#
# RUN 140 ===========================
# > MAX TRAFFIC: 5,216,047,547
# > START SERVER PLACEMENT AT INDEX: 2,595,952
# > END SERVER PLACEMENT ON INDEX: 3,836,880
# > NUMBER OF CLIENT MACHINES: 4,030,625
#
#
# RUN 141 ===========================
# > MAX TRAFFIC: 6,937,268,875
# > START SERVER PLACEMENT AT INDEX: 49,659
# > END SERVER PLACEMENT ON INDEX: 552,169
# > NUMBER OF CLIENT MACHINES: 571,899
#
#
# RUN 142 ===========================
# > MAX TRAFFIC: 6,541,048,282
# > START SERVER PLACEMENT AT INDEX: 3,470,833
# > END SERVER PLACEMENT ON INDEX: 4,090,620
# > NUMBER OF CLIENT MACHINES: 4,256,922
#
#
# RUN 143 ===========================
# > MAX TRAFFIC: 11,546,480,301
# > START SERVER PLACEMENT AT INDEX: 126,477
# > END SERVER PLACEMENT ON INDEX: 1,828,581
# > NUMBER OF CLIENT MACHINES: 1,847,282
#
#
# RUN 144 ===========================
# > MAX TRAFFIC: 6,363,712,631
# > START SERVER PLACEMENT AT INDEX: 1,363,447
# > END SERVER PLACEMENT ON INDEX: 3,290,356
# > NUMBER OF CLIENT MACHINES: 4,990,066
#
#
# RUN 145 ===========================
# > MAX TRAFFIC: 17,802,698,594
# > START SERVER PLACEMENT AT INDEX: 22,732
# > END SERVER PLACEMENT ON INDEX: 3,275,707
# > NUMBER OF CLIENT MACHINES: 3,713,222
#
#
# RUN 146 ===========================
# > MAX TRAFFIC: 1,207,202,151
# > START SERVER PLACEMENT AT INDEX: 54,436
# > END SERVER PLACEMENT ON INDEX: 85,483
# > NUMBER OF CLIENT MACHINES: 94,035
#
#
# RUN 147 ===========================
# > MAX TRAFFIC: 7,282,371,823
# > START SERVER PLACEMENT AT INDEX: 245,883
# > END SERVER PLACEMENT ON INDEX: 2,045,032
# > NUMBER OF CLIENT MACHINES: 4,966,760
#
#
# RUN 148 ===========================
# > MAX TRAFFIC: 10,703,583,708
# > START SERVER PLACEMENT AT INDEX: 2,449,791
# > END SERVER PLACEMENT ON INDEX: 3,651,632
# > NUMBER OF CLIENT MACHINES: 4,661,081
#
#
# RUN 149 ===========================
# > MAX TRAFFIC: 4,866,697,840
# > START SERVER PLACEMENT AT INDEX: 1,180,438
# > END SERVER PLACEMENT ON INDEX: 1,522,098
# > NUMBER OF CLIENT MACHINES: 2,806,521
#
#
# RUN 150 ===========================
# > MAX TRAFFIC: 5,292,637,182
# > START SERVER PLACEMENT AT INDEX: 1,518,978
# > END SERVER PLACEMENT ON INDEX: 2,213,976
# > NUMBER OF CLIENT MACHINES: 3,449,121
#
#
# RUN 151 ===========================
# > MAX TRAFFIC: 8,523,070,227
# > START SERVER PLACEMENT AT INDEX: 988,080
# > END SERVER PLACEMENT ON INDEX: 2,557,369
# > NUMBER OF CLIENT MACHINES: 4,036,777
#
#
# RUN 152 ===========================
# > MAX TRAFFIC: 7,781,987,525
# > START SERVER PLACEMENT AT INDEX: 1,189,206
# > END SERVER PLACEMENT ON INDEX: 2,313,670
# > NUMBER OF CLIENT MACHINES: 2,520,773
#
#
# RUN 153 ===========================
# > MAX TRAFFIC: 4,826,777,596
# > START SERVER PLACEMENT AT INDEX: 3,301,875
# > END SERVER PLACEMENT ON INDEX: 3,512,211
# > NUMBER OF CLIENT MACHINES: 4,306,275
#
#
# RUN 154 ===========================
# > MAX TRAFFIC: 9,396,668,764
# > START SERVER PLACEMENT AT INDEX: 2,784,021
# > END SERVER PLACEMENT ON INDEX: 4,564,411
# > NUMBER OF CLIENT MACHINES: 4,573,474
#
#
# RUN 155 ===========================
# > MAX TRAFFIC: 5,373,397,363
# > START SERVER PLACEMENT AT INDEX: 3,764
# > END SERVER PLACEMENT ON INDEX: 461,868
# > NUMBER OF CLIENT MACHINES: 1,915,961
#
#
# RUN 156 ===========================
# > MAX TRAFFIC: 6,638,336,673
# > START SERVER PLACEMENT AT INDEX: 3,050
# > END SERVER PLACEMENT ON INDEX: 887,696
# > NUMBER OF CLIENT MACHINES: 1,440,733
#
#
# RUN 157 ===========================
# > MAX TRAFFIC: 8,127,888,582
# > START SERVER PLACEMENT AT INDEX: 1,942,779
# > END SERVER PLACEMENT ON INDEX: 3,613,087
# > NUMBER OF CLIENT MACHINES: 3,613,870
#
#
# RUN 158 ===========================
# > MAX TRAFFIC: 11,079,307,407
# > START SERVER PLACEMENT AT INDEX: 803,138
# > END SERVER PLACEMENT ON INDEX: 2,537,950
# > NUMBER OF CLIENT MACHINES: 3,683,108
#
#
# RUN 159 ===========================
# > MAX TRAFFIC: 268,586,377
# > START SERVER PLACEMENT AT INDEX: 8,347
# > END SERVER PLACEMENT ON INDEX: 11,413
# > NUMBER OF CLIENT MACHINES: 21,160
#
#
# RUN 160 ===========================
# > MAX TRAFFIC: 4,383,220,812
# > START SERVER PLACEMENT AT INDEX: 163,737
# > END SERVER PLACEMENT ON INDEX: 810,517
# > NUMBER OF CLIENT MACHINES: 2,240,810
#
#
# RUN 161 ===========================
# > MAX TRAFFIC: 5,996,292,251
# > START SERVER PLACEMENT AT INDEX: 199,241
# > END SERVER PLACEMENT ON INDEX: 1,627,082
# > NUMBER OF CLIENT MACHINES: 1,682,373
#
#
# RUN 162 ===========================
# > MAX TRAFFIC: 6,982,311,376
# > START SERVER PLACEMENT AT INDEX: 11,499
# > END SERVER PLACEMENT ON INDEX: 2,326,098
# > NUMBER OF CLIENT MACHINES: 3,167,503
#
#
# RUN 163 ===========================
# > MAX TRAFFIC: 2,933,116,555
# > START SERVER PLACEMENT AT INDEX: 215,971
# > END SERVER PLACEMENT ON INDEX: 440,107
# > NUMBER OF CLIENT MACHINES: 440,551
#
#
# RUN 164 ===========================
# > MAX TRAFFIC: 16,902,242,041
# > START SERVER PLACEMENT AT INDEX: 795,143
# > END SERVER PLACEMENT ON INDEX: 2,388,237
# > NUMBER OF CLIENT MACHINES: 2,816,117
#
#
# RUN 165 ===========================
# > MAX TRAFFIC: 12,200,423,082
# > START SERVER PLACEMENT AT INDEX: 2,096,719
# > END SERVER PLACEMENT ON INDEX: 3,682,701
# > NUMBER OF CLIENT MACHINES: 4,667,992
#
#
# RUN 166 ===========================
# > MAX TRAFFIC: 5,916,871,949
# > START SERVER PLACEMENT AT INDEX: 208,659
# > END SERVER PLACEMENT ON INDEX: 3,401,421
# > NUMBER OF CLIENT MACHINES: 3,401,422
#
#
# RUN 167 ===========================
# > MAX TRAFFIC: 13,313,300,484
# > START SERVER PLACEMENT AT INDEX: 120,464
# > END SERVER PLACEMENT ON INDEX: 3,035,017
# > NUMBER OF CLIENT MACHINES: 3,035,928
#
#
# RUN 168 ===========================
# > MAX TRAFFIC: 9,117,097,268
# > START SERVER PLACEMENT AT INDEX: 41,002
# > END SERVER PLACEMENT ON INDEX: 1,098,238
# > NUMBER OF CLIENT MACHINES: 3,682,660
#
#
# RUN 169 ===========================
# > MAX TRAFFIC: 4,364,467,763
# > START SERVER PLACEMENT AT INDEX: 168,187
# > END SERVER PLACEMENT ON INDEX: 519,752
# > NUMBER OF CLIENT MACHINES: 853,756
#
#
# RUN 170 ===========================
# > MAX TRAFFIC: 6,116,977,592
# > START SERVER PLACEMENT AT INDEX: 1,324,754
# > END SERVER PLACEMENT ON INDEX: 2,571,242
# > NUMBER OF CLIENT MACHINES: 3,015,657
#
#
# RUN 171 ===========================
# > MAX TRAFFIC: 5,916,773,680
# > START SERVER PLACEMENT AT INDEX: 730,082
# > END SERVER PLACEMENT ON INDEX: 1,292,344
# > NUMBER OF CLIENT MACHINES: 1,701,760
#
#
# RUN 172 ===========================
# > MAX TRAFFIC: 5,020,080,637
# > START SERVER PLACEMENT AT INDEX: 300,390
# > END SERVER PLACEMENT ON INDEX: 847,259
# > NUMBER OF CLIENT MACHINES: 932,442
# RUN 173 ===========================
# > MAX TRAFFIC: 7,881,779,853
# > START SERVER PLACEMENT AT INDEX: 109,013
# > END SERVER PLACEMENT ON INDEX: 524,563
# > NUMBER OF CLIENT MACHINES: 3,445,606
#
#
# RUN 174 ===========================
# > MAX TRAFFIC: 7,278,505,703
# > START SERVER PLACEMENT AT INDEX: 56,681
# > END SERVER PLACEMENT ON INDEX: 1,311,585
# > NUMBER OF CLIENT MACHINES: 1,515,226
#
#
# RUN 175 ===========================
# > MAX TRAFFIC: 3,823,997,529
# > START SERVER PLACEMENT AT INDEX: 313,774
# > END SERVER PLACEMENT ON INDEX: 697,469
# > NUMBER OF CLIENT MACHINES: 891,286
#
#
# RUN 176 ===========================
# > MAX TRAFFIC: 8,693,405,005
# > START SERVER PLACEMENT AT INDEX: 345,244
# > END SERVER PLACEMENT ON INDEX: 1,467,985
# > NUMBER OF CLIENT MACHINES: 3,585,593
#
#
# RUN 177 ===========================
# > MAX TRAFFIC: 1,648,261,005
# > START SERVER PLACEMENT AT INDEX: 14,321
# > END SERVER PLACEMENT ON INDEX: 53,162
# > NUMBER OF CLIENT MACHINES: 692,698
#
#
# RUN 178 ===========================
# > MAX TRAFFIC: 2,588,528,577
# > START SERVER PLACEMENT AT INDEX: 27,753
# > END SERVER PLACEMENT ON INDEX: 269,911
# > NUMBER OF CLIENT MACHINES: 1,983,403
#
#
# RUN 179 ===========================
# > MAX TRAFFIC: 2,232,445,425
# > START SERVER PLACEMENT AT INDEX: 6,915
# > END SERVER PLACEMENT ON INDEX: 182,782
# > NUMBER OF CLIENT MACHINES: 183,026
#
#
# RUN 180 ===========================
# > MAX TRAFFIC: 7,450,411,559
# > START SERVER PLACEMENT AT INDEX: 638,880
# > END SERVER PLACEMENT ON INDEX: 2,657,111
# > NUMBER OF CLIENT MACHINES: 2,828,008
#
#
# RUN 181 ===========================
# > MAX TRAFFIC: 6,512,520,413
# > START SERVER PLACEMENT AT INDEX: 4,327
# > END SERVER PLACEMENT ON INDEX: 969,680
# > NUMBER OF CLIENT MACHINES: 4,658,388
#
#
# RUN 182 ===========================
# > MAX TRAFFIC: 2,939,620,401
# > START SERVER PLACEMENT AT INDEX: 1,035,446
# > END SERVER PLACEMENT ON INDEX: 1,527,994
# > NUMBER OF CLIENT MACHINES: 1,801,919
#
#
# RUN 183 ===========================
# > MAX TRAFFIC: 5,010,077,329
# > START SERVER PLACEMENT AT INDEX: 651,758
# > END SERVER PLACEMENT ON INDEX: 1,252,745
# > NUMBER OF CLIENT MACHINES: 1,872,697
#
#
# RUN 184 ===========================
# > MAX TRAFFIC: 5,977,317,715
# > START SERVER PLACEMENT AT INDEX: 2,477,725
# > END SERVER PLACEMENT ON INDEX: 3,597,822
# > NUMBER OF CLIENT MACHINES: 3,728,423
#
#
# RUN 185 ===========================
# > MAX TRAFFIC: 7,723,594,719
# > START SERVER PLACEMENT AT INDEX: 794,019
# > END SERVER PLACEMENT ON INDEX: 1,735,801
# > NUMBER OF CLIENT MACHINES: 3,482,780
#
#
# RUN 186 ===========================
# > MAX TRAFFIC: 5,130,375,901
# > START SERVER PLACEMENT AT INDEX: 62,515
# > END SERVER PLACEMENT ON INDEX: 1,419,593
# > NUMBER OF CLIENT MACHINES: 3,030,433
#
#
# RUN 187 ===========================
# > MAX TRAFFIC: 7,179,461,731
# > START SERVER PLACEMENT AT INDEX: 541,733
# > END SERVER PLACEMENT ON INDEX: 2,628,944
# > NUMBER OF CLIENT MACHINES: 2,839,434
#
#
# RUN 188 ===========================
# > MAX TRAFFIC: 3,831,771,189
# > START SERVER PLACEMENT AT INDEX: 35,576
# > END SERVER PLACEMENT ON INDEX: 589,639
# > NUMBER OF CLIENT MACHINES: 590,025
#
#
# RUN 189 ===========================
# > MAX TRAFFIC: 4,948,598,884
# > START SERVER PLACEMENT AT INDEX: 1,523,221
# > END SERVER PLACEMENT ON INDEX: 1,933,085
# > NUMBER OF CLIENT MACHINES: 2,331,426
#
#
# RUN 190 ===========================
# > MAX TRAFFIC: 5,433,291,555
# > START SERVER PLACEMENT AT INDEX: 1,054,227
# > END SERVER PLACEMENT ON INDEX: 1,418,056
# > NUMBER OF CLIENT MACHINES: 3,111,790
#
#
# RUN 191 ===========================
# > MAX TRAFFIC: 9,282,872,367
# > START SERVER PLACEMENT AT INDEX: 1,039,257
# > END SERVER PLACEMENT ON INDEX: 2,857,110
# > NUMBER OF CLIENT MACHINES: 3,775,082
#
#
# RUN 192 ===========================
# > MAX TRAFFIC: 7,727,662,800
# > START SERVER PLACEMENT AT INDEX: 100,904
# > END SERVER PLACEMENT ON INDEX: 832,702
# > NUMBER OF CLIENT MACHINES: 837,309
#
#
# RUN 193 ===========================
# > MAX TRAFFIC: 4,854,901,412
# > START SERVER PLACEMENT AT INDEX: 891,615
# > END SERVER PLACEMENT ON INDEX: 2,713,211
# > NUMBER OF CLIENT MACHINES: 4,037,971
#
#
# RUN 194 ===========================
# > MAX TRAFFIC: 4,929,391,091
# > START SERVER PLACEMENT AT INDEX: 954,651
# > END SERVER PLACEMENT ON INDEX: 1,787,892
# > NUMBER OF CLIENT MACHINES: 2,793,279
#
#
# RUN 195 ===========================
# > MAX TRAFFIC: 15,158,281,898
# > START SERVER PLACEMENT AT INDEX: 181,248
# > END SERVER PLACEMENT ON INDEX: 2,446,630
# > NUMBER OF CLIENT MACHINES: 4,721,402
#
#
# RUN 196 ===========================
# > MAX TRAFFIC: 2,361,216,470
# > START SERVER PLACEMENT AT INDEX: 372,715
# > END SERVER PLACEMENT ON INDEX: 503,916
# > NUMBER OF CLIENT MACHINES: 525,776
#
#
# RUN 197 ===========================
# > MAX TRAFFIC: 4,733,092,310
# > START SERVER PLACEMENT AT INDEX: 1,034,331
# > END SERVER PLACEMENT ON INDEX: 1,602,414
# > NUMBER OF CLIENT MACHINES: 2,205,869
#
#
# RUN 198 ===========================
# > MAX TRAFFIC: 10,228,897,836
# > START SERVER PLACEMENT AT INDEX: 1,443,347
# > END SERVER PLACEMENT ON INDEX: 3,490,323
# > NUMBER OF CLIENT MACHINES: 3,503,762
#
#
# RUN 199 ===========================
# > MAX TRAFFIC: 3,872,113,144
# > START SERVER PLACEMENT AT INDEX: 505,062
# > END SERVER PLACEMENT ON INDEX: 769,047
# > NUMBER OF CLIENT MACHINES: 955,383
#
#
# RUN 200 ===========================
# > MAX TRAFFIC: 1,645,526,581
# > START SERVER PLACEMENT AT INDEX: 72,146
# > END SERVER PLACEMENT ON INDEX: 124,309
# > NUMBER OF CLIENT MACHINES: 170,277
#
#
# RUN 201 ===========================
# > MAX TRAFFIC: 3,572,040,143
# > START SERVER PLACEMENT AT INDEX: 56,547
# > END SERVER PLACEMENT ON INDEX: 627,930
# > NUMBER OF CLIENT MACHINES: 849,330
#
#
# RUN 202 ===========================
# > MAX TRAFFIC: 5,409,214,762
# > START SERVER PLACEMENT AT INDEX: 166,966
# > END SERVER PLACEMENT ON INDEX: 1,862,784
# > NUMBER OF CLIENT MACHINES: 1,864,488
#
#
# RUN 203 ===========================
# > MAX TRAFFIC: 5,421,823,076
# > START SERVER PLACEMENT AT INDEX: 660,082
# > END SERVER PLACEMENT ON INDEX: 1,030,224
# > NUMBER OF CLIENT MACHINES: 1,092,799
#
#
# RUN 204 ===========================
# > MAX TRAFFIC: 2,078,659,500
# > START SERVER PLACEMENT AT INDEX: 63,172
# > END SERVER PLACEMENT ON INDEX: 134,451
# > NUMBER OF CLIENT MACHINES: 194,885
#
#
# RUN 205 ===========================
# > MAX TRAFFIC: 4,757,705,751
# > START SERVER PLACEMENT AT INDEX: 1,359
# > END SERVER PLACEMENT ON INDEX: 889,469
# > NUMBER OF CLIENT MACHINES: 1,309,968
#
#
# RUN 206 ===========================
# > MAX TRAFFIC: 15,757,704,243
# > START SERVER PLACEMENT AT INDEX: 652,192
# > END SERVER PLACEMENT ON INDEX: 4,376,306
# > NUMBER OF CLIENT MACHINES: 4,565,956
#
#
# RUN 207 ===========================
# > MAX TRAFFIC: 16,052,031,872
# > START SERVER PLACEMENT AT INDEX: 939,295
# > END SERVER PLACEMENT ON INDEX: 4,102,351
# > NUMBER OF CLIENT MACHINES: 4,406,367
#
#
# RUN 208 ===========================
# > MAX TRAFFIC: 10,889,239,667
# > START SERVER PLACEMENT AT INDEX: 1,249,513
# > END SERVER PLACEMENT ON INDEX: 4,009,866
# > NUMBER OF CLIENT MACHINES: 4,221,857
#
#
# RUN 209 ===========================
# > MAX TRAFFIC: 3,879,970,434
# > START SERVER PLACEMENT AT INDEX: 152,029
# > END SERVER PLACEMENT ON INDEX: 1,517,456
# > NUMBER OF CLIENT MACHINES: 1,912,818
#
#
# RUN 210 ===========================
# > MAX TRAFFIC: 7,427,878,026
# > START SERVER PLACEMENT AT INDEX: 32,736
# > END SERVER PLACEMENT ON INDEX: 788,082
# > NUMBER OF CLIENT MACHINES: 933,832
#
#
# RUN 211 ===========================
# > MAX TRAFFIC: 2,874,881,592
# > START SERVER PLACEMENT AT INDEX: 349,308
# > END SERVER PLACEMENT ON INDEX: 436,997
# > NUMBER OF CLIENT MACHINES: 1,213,008
#
#
# RUN 212 ===========================
# > MAX TRAFFIC: 5,456,923,347
# > START SERVER PLACEMENT AT INDEX: 1,921,099
# > END SERVER PLACEMENT ON INDEX: 2,305,058
# > NUMBER OF CLIENT MACHINES: 3,301,303
#
#
# RUN 213 ===========================
# > MAX TRAFFIC: 2,330,450,954
# > START SERVER PLACEMENT AT INDEX: 177,478
# > END SERVER PLACEMENT ON INDEX: 303,611
# > NUMBER OF CLIENT MACHINES: 1,065,322
#
#
# RUN 214 ===========================
# > MAX TRAFFIC: 3,544,466,661
# > START SERVER PLACEMENT AT INDEX: 294,106
# > END SERVER PLACEMENT ON INDEX: 874,751
# > NUMBER OF CLIENT MACHINES: 987,877
#
#
# RUN 215 ===========================
# > MAX TRAFFIC: 12,770,925,328
# > START SERVER PLACEMENT AT INDEX: 1,373,542
# > END SERVER PLACEMENT ON INDEX: 4,707,431
# > NUMBER OF CLIENT MACHINES: 4,707,452
# RUN 216 ===========================
# > MAX TRAFFIC: 11,441,015,081
# > START SERVER PLACEMENT AT INDEX: 2,700,605
# > END SERVER PLACEMENT ON INDEX: 4,908,897
# > NUMBER OF CLIENT MACHINES: 4,912,538
#
#
# RUN 217 ===========================
# > MAX TRAFFIC: 8,262,820,807
# > START SERVER PLACEMENT AT INDEX: 3,538,895
# > END SERVER PLACEMENT ON INDEX: 4,198,419
# > NUMBER OF CLIENT MACHINES: 4,199,728
#
#
# RUN 218 ===========================
# > MAX TRAFFIC: 5,971,375,325
# > START SERVER PLACEMENT AT INDEX: 3,350,419
# > END SERVER PLACEMENT ON INDEX: 4,392,046
# > NUMBER OF CLIENT MACHINES: 4,456,067
#
#
# RUN 219 ===========================
# > MAX TRAFFIC: 8,174,874,169
# > START SERVER PLACEMENT AT INDEX: 103,328
# > END SERVER PLACEMENT ON INDEX: 835,143
# > NUMBER OF CLIENT MACHINES: 2,321,913
#
#
# RUN 220 ===========================
# > MAX TRAFFIC: 8,497,070,811
# > START SERVER PLACEMENT AT INDEX: 865,538
# > END SERVER PLACEMENT ON INDEX: 2,521,480
# > NUMBER OF CLIENT MACHINES: 2,939,222
#
#
# RUN 221 ===========================
# > MAX TRAFFIC: 2,190,224,185
# > START SERVER PLACEMENT AT INDEX: 153,521
# > END SERVER PLACEMENT ON INDEX: 227,494
# > NUMBER OF CLIENT MACHINES: 525,831
#
#
# RUN 222 ===========================
# > MAX TRAFFIC: 9,537,920,924
# > START SERVER PLACEMENT AT INDEX: 464,412
# > END SERVER PLACEMENT ON INDEX: 1,639,275
# > NUMBER OF CLIENT MACHINES: 4,283,115
#
#
# RUN 223 ===========================
# > MAX TRAFFIC: 8,433,898,869
# > START SERVER PLACEMENT AT INDEX: 174,384
# > END SERVER PLACEMENT ON INDEX: 2,960,255
# > NUMBER OF CLIENT MACHINES: 3,729,186
#
#
# RUN 224 ===========================
# > MAX TRAFFIC: 11,555,250,983
# > START SERVER PLACEMENT AT INDEX: 1,363,562
# > END SERVER PLACEMENT ON INDEX: 3,170,075
# > NUMBER OF CLIENT MACHINES: 4,216,109
#
#
# RUN 225 ===========================
# > MAX TRAFFIC: 7,716,685,475
# > START SERVER PLACEMENT AT INDEX: 798,521
# > END SERVER PLACEMENT ON INDEX: 3,349,291
# > NUMBER OF CLIENT MACHINES: 3,822,130
#
#
# RUN 226 ===========================
# > MAX TRAFFIC: 6,628,560,772
# > START SERVER PLACEMENT AT INDEX: 162,726
# > END SERVER PLACEMENT ON INDEX: 4,139,514
# > NUMBER OF CLIENT MACHINES: 4,476,170
#
#
# RUN 227 ===========================
# > MAX TRAFFIC: 7,765,862,671
# > START SERVER PLACEMENT AT INDEX: 1,081,799
# > END SERVER PLACEMENT ON INDEX: 1,921,035
# > NUMBER OF CLIENT MACHINES: 1,925,485
#
#
# RUN 228 ===========================
# > MAX TRAFFIC: 8,119,003,306
# > START SERVER PLACEMENT AT INDEX: 2,504,584
# > END SERVER PLACEMENT ON INDEX: 4,177,930
# > NUMBER OF CLIENT MACHINES: 4,684,605
#
#
# RUN 229 ===========================
# > MAX TRAFFIC: 7,644,165,057
# > START SERVER PLACEMENT AT INDEX: 325,370
# > END SERVER PLACEMENT ON INDEX: 2,590,340
# > NUMBER OF CLIENT MACHINES: 3,502,932
#
#
# RUN 230 ===========================
# > MAX TRAFFIC: 2,746,377,854
# > START SERVER PLACEMENT AT INDEX: 333,928
# > END SERVER PLACEMENT ON INDEX: 458,252
# > NUMBER OF CLIENT MACHINES: 917,277
#
#
# RUN 231 ===========================
# > MAX TRAFFIC: 6,272,855,003
# > START SERVER PLACEMENT AT INDEX: 17,096
# > END SERVER PLACEMENT ON INDEX: 1,197,517
# > NUMBER OF CLIENT MACHINES: 3,046,683
#
#
# RUN 232 ===========================
# > MAX TRAFFIC: 10,164,228,516
# > START SERVER PLACEMENT AT INDEX: 2,713,422
# > END SERVER PLACEMENT ON INDEX: 4,404,982
# > NUMBER OF CLIENT MACHINES: 4,711,328
#
#
# RUN 233 ===========================
# > MAX TRAFFIC: 14,659,234,093
# > START SERVER PLACEMENT AT INDEX: 105,600
# > END SERVER PLACEMENT ON INDEX: 3,138,433
# > NUMBER OF CLIENT MACHINES: 3,638,649
#
#
# RUN 234 ===========================
# > MAX TRAFFIC: 10,828,350,270
# > START SERVER PLACEMENT AT INDEX: 2,422,133
# > END SERVER PLACEMENT ON INDEX: 4,307,322
# > NUMBER OF CLIENT MACHINES: 4,316,092
#
#
# RUN 235 ===========================
# > MAX TRAFFIC: 3,660,514,817
# > START SERVER PLACEMENT AT INDEX: 375,354
# > END SERVER PLACEMENT ON INDEX: 606,260
# > NUMBER OF CLIENT MACHINES: 690,319
#
#
# RUN 236 ===========================
# > MAX TRAFFIC: 2,870,899,498
# > START SERVER PLACEMENT AT INDEX: 47,536
# > END SERVER PLACEMENT ON INDEX: 235,955
# > NUMBER OF CLIENT MACHINES: 461,692
#
#
# RUN 237 ===========================
# > MAX TRAFFIC: 7,106,866,967
# > START SERVER PLACEMENT AT INDEX: 732,137
# > END SERVER PLACEMENT ON INDEX: 2,110,316
# > NUMBER OF CLIENT MACHINES: 3,607,562
#
#
# RUN 238 ===========================
# > MAX TRAFFIC: 10,265,539,097
# > START SERVER PLACEMENT AT INDEX: 163,505
# > END SERVER PLACEMENT ON INDEX: 2,605,664
# > NUMBER OF CLIENT MACHINES: 2,606,002
#
#
# RUN 239 ===========================
# > MAX TRAFFIC: 7,301,840,006
# > START SERVER PLACEMENT AT INDEX: 2,414,348
# > END SERVER PLACEMENT ON INDEX: 3,205,738
# > NUMBER OF CLIENT MACHINES: 4,203,278
#
#
# RUN 240 ===========================
# > MAX TRAFFIC: 5,676,195,966
# > START SERVER PLACEMENT AT INDEX: 953,176
# > END SERVER PLACEMENT ON INDEX: 1,482,049
# > NUMBER OF CLIENT MACHINES: 2,300,468
#
#
# RUN 241 ===========================
# > MAX TRAFFIC: 2,280,442,715
# > START SERVER PLACEMENT AT INDEX: 863,972
# > END SERVER PLACEMENT ON INDEX: 958,346
# > NUMBER OF CLIENT MACHINES: 1,003,216
#
#
# RUN 242 ===========================
# > MAX TRAFFIC: 4,741,740,261
# > START SERVER PLACEMENT AT INDEX: 28,400
# > END SERVER PLACEMENT ON INDEX: 416,884
# > NUMBER OF CLIENT MACHINES: 1,184,252
#
#
# RUN 243 ===========================
# > MAX TRAFFIC: 4,611,832,271
# > START SERVER PLACEMENT AT INDEX: 2,266,352
# > END SERVER PLACEMENT ON INDEX: 2,687,793
# > NUMBER OF CLIENT MACHINES: 3,857,670
#
#
# RUN 244 ===========================
# > MAX TRAFFIC: 10,348,519,337
# > START SERVER PLACEMENT AT INDEX: 26,919
# > END SERVER PLACEMENT ON INDEX: 1,996,081
# > NUMBER OF CLIENT MACHINES: 2,350,449
#
#
# RUN 245 ===========================
# > MAX TRAFFIC: 6,726,795,918
# > START SERVER PLACEMENT AT INDEX: 1,232,306
# > END SERVER PLACEMENT ON INDEX: 3,638,314
# > NUMBER OF CLIENT MACHINES: 4,508,716
#
#
# RUN 246 ===========================
# > MAX TRAFFIC: 5,451,661,389
# > START SERVER PLACEMENT AT INDEX: 78,909
# > END SERVER PLACEMENT ON INDEX: 1,283,360
# > NUMBER OF CLIENT MACHINES: 1,350,492
#
#
# RUN 247 ===========================
# > MAX TRAFFIC: 5,144,298,342
# > START SERVER PLACEMENT AT INDEX: 561,810
# > END SERVER PLACEMENT ON INDEX: 1,089,265
# > NUMBER OF CLIENT MACHINES: 1,936,592
#
#
# RUN 248 ===========================
# > MAX TRAFFIC: 9,159,382,267
# > START SERVER PLACEMENT AT INDEX: 27,713
# > END SERVER PLACEMENT ON INDEX: 2,066,887
# > NUMBER OF CLIENT MACHINES: 4,233,341
#
#
# RUN 249 ===========================
# > MAX TRAFFIC: 3,486,949,707
# > START SERVER PLACEMENT AT INDEX: 1,356,058
# > END SERVER PLACEMENT ON INDEX: 1,615,401
# > NUMBER OF CLIENT MACHINES: 1,678,577
#
#
# RUN 250 ===========================
# > MAX TRAFFIC: 8,167,856,566
# > START SERVER PLACEMENT AT INDEX: 2,773,574
# > END SERVER PLACEMENT ON INDEX: 4,183,160
# > NUMBER OF CLIENT MACHINES: 4,471,749
#
#
# RUN 251 ===========================
# > MAX TRAFFIC: 11,512,670,321
# ...
# > MAX TRAFFIC: 7,876,806,807
# > START SERVER PLACEMENT AT INDEX: 1,988,971
# > END SERVER PLACEMENT ON INDEX: 2,416,846
# > NUMBER OF CLIENT MACHINES: 2,762,211
#
#
# RUN 959 ===========================
# > MAX TRAFFIC: 8,591,418,335
# > START SERVER PLACEMENT AT INDEX: 994,747
# > END SERVER PLACEMENT ON INDEX: 3,679,403
# > NUMBER OF CLIENT MACHINES: 4,647,438
#
#
# RUN 960 ===========================
# > MAX TRAFFIC: 3,724,414,393
# > START SERVER PLACEMENT AT INDEX: 186,297
# > END SERVER PLACEMENT ON INDEX: 422,502
# > NUMBER OF CLIENT MACHINES: 459,251
#
#
# RUN 961 ===========================
# > MAX TRAFFIC: 8,956,993,814
# > START SERVER PLACEMENT AT INDEX: 2,673,447
# > END SERVER PLACEMENT ON INDEX: 4,824,613
# > NUMBER OF CLIENT MACHINES: 4,826,124
#
#
# RUN 962 ===========================
# > MAX TRAFFIC: 11,646,011,976
# > START SERVER PLACEMENT AT INDEX: 246,821
# > END SERVER PLACEMENT ON INDEX: 1,840,928
# > NUMBER OF CLIENT MACHINES: 3,227,196
#
#
# RUN 963 ===========================
# > MAX TRAFFIC: 9,281,887,432
# > START SERVER PLACEMENT AT INDEX: 753,796
# > END SERVER PLACEMENT ON INDEX: 2,532,405
# > NUMBER OF CLIENT MACHINES: 3,532,797
#
#
# RUN 964 ===========================
# > MAX TRAFFIC: 5,619,903,942
# > START SERVER PLACEMENT AT INDEX: 1,832,965
# > END SERVER PLACEMENT ON INDEX: 2,107,906
# > NUMBER OF CLIENT MACHINES: 2,238,517
#
#
# RUN 965 ===========================
# > MAX TRAFFIC: 9,708,302,320
# > START SERVER PLACEMENT AT INDEX: 2,168,959
# > END SERVER PLACEMENT ON INDEX: 3,595,719
# > NUMBER OF CLIENT MACHINES: 4,487,755
#
#
# RUN 966 ===========================
# > MAX TRAFFIC: 10,922,892,425
# > START SERVER PLACEMENT AT INDEX: 1,458,303
# > END SERVER PLACEMENT ON INDEX: 2,928,392
# > NUMBER OF CLIENT MACHINES: 3,062,111
#
#
# RUN 967 ===========================
# > MAX TRAFFIC: 1,929,227,777
# > START SERVER PLACEMENT AT INDEX: 188,473
# > END SERVER PLACEMENT ON INDEX: 461,756
# > NUMBER OF CLIENT MACHINES: 581,674
#
#
# RUN 968 ===========================
# > MAX TRAFFIC: 6,654,188,398
# > START SERVER PLACEMENT AT INDEX: 107,119
# > END SERVER PLACEMENT ON INDEX: 1,859,125
# > NUMBER OF CLIENT MACHINES: 3,694,923
#
#
# RUN 969 ===========================
# > MAX TRAFFIC: 5,836,699,164
# > START SERVER PLACEMENT AT INDEX: 429,576
# > END SERVER PLACEMENT ON INDEX: 1,166,673
# > NUMBER OF CLIENT MACHINES: 2,331,667
#
#
# RUN 970 ===========================
# > MAX TRAFFIC: 4,661,419,454
# > START SERVER PLACEMENT AT INDEX: 54,104
# > END SERVER PLACEMENT ON INDEX: 456,356
# > NUMBER OF CLIENT MACHINES: 1,010,721
#
#
# RUN 971 ===========================
# > MAX TRAFFIC: 5,699,541,418
# > START SERVER PLACEMENT AT INDEX: 311,294
# > END SERVER PLACEMENT ON INDEX: 692,605
# > NUMBER OF CLIENT MACHINES: 4,299,111
#
#
# RUN 972 ===========================
# > MAX TRAFFIC: 5,722,652,856
# > START SERVER PLACEMENT AT INDEX: 23,833
# > END SERVER PLACEMENT ON INDEX: 535,153
# > NUMBER OF CLIENT MACHINES: 1,435,663
#
#
# RUN 973 ===========================
# > MAX TRAFFIC: 2,947,112,027
# > START SERVER PLACEMENT AT INDEX: 279,771
# > END SERVER PLACEMENT ON INDEX: 599,475
# > NUMBER OF CLIENT MACHINES: 1,203,669
#
#
# RUN 974 ===========================
# > MAX TRAFFIC: 3,366,166,220
# > START SERVER PLACEMENT AT INDEX: 580,373
# > END SERVER PLACEMENT ON INDEX: 703,890
# > NUMBER OF CLIENT MACHINES: 2,068,864
#
#
# RUN 975 ===========================
# > MAX TRAFFIC: 5,282,416,004
# > START SERVER PLACEMENT AT INDEX: 69,230
# > END SERVER PLACEMENT ON INDEX: 627,385
# > NUMBER OF CLIENT MACHINES: 2,676,958
#
#
# RUN 976 ===========================
# > MAX TRAFFIC: 483,455,601
# > START SERVER PLACEMENT AT INDEX: 2,552
# > END SERVER PLACEMENT ON INDEX: 7,340
# > NUMBER OF CLIENT MACHINES: 15,937
#
#
# RUN 977 ===========================
# > MAX TRAFFIC: 7,313,834,202
# > START SERVER PLACEMENT AT INDEX: 829,584
# > END SERVER PLACEMENT ON INDEX: 1,523,640
# > NUMBER OF CLIENT MACHINES: 3,643,085
#
#
# RUN 978 ===========================
# > MAX TRAFFIC: 4,822,507,225
# > START SERVER PLACEMENT AT INDEX: 3,358,448
# > END SERVER PLACEMENT ON INDEX: 4,171,974
# > NUMBER OF CLIENT MACHINES: 4,377,543
#
#
# RUN 979 ===========================
# > MAX TRAFFIC: 10,176,483,484
# > START SERVER PLACEMENT AT INDEX: 42,292
# > END SERVER PLACEMENT ON INDEX: 4,332,276
# > NUMBER OF CLIENT MACHINES: 4,362,127
#
#
# RUN 980 ===========================
# > MAX TRAFFIC: 6,395,363,594
# > START SERVER PLACEMENT AT INDEX: 212,734
# > END SERVER PLACEMENT ON INDEX: 2,515,744
# > NUMBER OF CLIENT MACHINES: 4,258,934
#
#
# RUN 981 ===========================
# > MAX TRAFFIC: 4,454,027,600
# > START SERVER PLACEMENT AT INDEX: 38,398
# > END SERVER PLACEMENT ON INDEX: 1,095,767
# > NUMBER OF CLIENT MACHINES: 2,037,711
#
#
# RUN 982 ===========================
# > MAX TRAFFIC: 3,745,367,061
# > START SERVER PLACEMENT AT INDEX: 311,302
# > END SERVER PLACEMENT ON INDEX: 647,852
# > NUMBER OF CLIENT MACHINES: 944,931
#
#
# RUN 983 ===========================
# > MAX TRAFFIC: 7,719,651,633
# > START SERVER PLACEMENT AT INDEX: 732,766
# > END SERVER PLACEMENT ON INDEX: 1,827,981
# > NUMBER OF CLIENT MACHINES: 2,806,317
#
#
# RUN 984 ===========================
# > MAX TRAFFIC: 16,112,851,216
# > START SERVER PLACEMENT AT INDEX: 729,185
# > END SERVER PLACEMENT ON INDEX: 2,637,286
# > NUMBER OF CLIENT MACHINES: 2,983,705
#
#
# RUN 985 ===========================
# > MAX TRAFFIC: 4,062,175,425
# > START SERVER PLACEMENT AT INDEX: 44,550
# > END SERVER PLACEMENT ON INDEX: 1,294,262
# > NUMBER OF CLIENT MACHINES: 3,304,569
#
#
# RUN 986 ===========================
# > MAX TRAFFIC: 9,822,417,524
# > START SERVER PLACEMENT AT INDEX: 24,962
# > END SERVER PLACEMENT ON INDEX: 3,619,742
# > NUMBER OF CLIENT MACHINES: 4,509,602
#
#
# RUN 987 ===========================
# > MAX TRAFFIC: 8,899,500,468
# > START SERVER PLACEMENT AT INDEX: 17,210
# > END SERVER PLACEMENT ON INDEX: 3,474,938
# > NUMBER OF CLIENT MACHINES: 3,499,040
#
#
# RUN 988 ===========================
# > MAX TRAFFIC: 7,171,235,658
# > START SERVER PLACEMENT AT INDEX: 1,127,380
# > END SERVER PLACEMENT ON INDEX: 2,333,095
# > NUMBER OF CLIENT MACHINES: 4,053,210
#
#
# RUN 989 ===========================
# > MAX TRAFFIC: 10,981,158,821
# > START SERVER PLACEMENT AT INDEX: 1,734,730
# > END SERVER PLACEMENT ON INDEX: 3,238,063
# > NUMBER OF CLIENT MACHINES: 3,626,685
#
#
# RUN 990 ===========================
# > MAX TRAFFIC: 5,490,388,800
# > START SERVER PLACEMENT AT INDEX: 583,753
# > END SERVER PLACEMENT ON INDEX: 1,024,818
# > NUMBER OF CLIENT MACHINES: 1,185,927
#
#
# RUN 991 ===========================
# > MAX TRAFFIC: 3,535,041,460
# > START SERVER PLACEMENT AT INDEX: 901,804
# > END SERVER PLACEMENT ON INDEX: 1,212,328
# > NUMBER OF CLIENT MACHINES: 1,311,443
# RUN 992 ===========================
# > MAX TRAFFIC: 9,032,974,380
# > START SERVER PLACEMENT AT INDEX: 2,870
# > END SERVER PLACEMENT ON INDEX: 2,401,365
# > NUMBER OF CLIENT MACHINES: 2,413,665
#
#
# RUN 993 ===========================
# > MAX TRAFFIC: 7,979,969,311
# > START SERVER PLACEMENT AT INDEX: 232,830
# > END SERVER PLACEMENT ON INDEX: 1,384,107
# > NUMBER OF CLIENT MACHINES: 2,873,158
#
#
# RUN 994 ===========================
# > MAX TRAFFIC: 4,384,038,929
# > START SERVER PLACEMENT AT INDEX: 7,357
# > END SERVER PLACEMENT ON INDEX: 450,559
# > NUMBER OF CLIENT MACHINES: 2,024,474
#
#
# RUN 995 ===========================
# > MAX TRAFFIC: 4,839,520,231
# > START SERVER PLACEMENT AT INDEX: 11,243
# > END SERVER PLACEMENT ON INDEX: 1,106,024
# > NUMBER OF CLIENT MACHINES: 3,355,307
#
#
# RUN 996 ===========================
# > MAX TRAFFIC: 707,727,314
# > START SERVER PLACEMENT AT INDEX: 2,531
# > END SERVER PLACEMENT ON INDEX: 13,975
# > NUMBER OF CLIENT MACHINES: 53,513
#
#
# RUN 997 ===========================
# > MAX TRAFFIC: 3,004,577,866
# > START SERVER PLACEMENT AT INDEX: 15,753
# > END SERVER PLACEMENT ON INDEX: 263,637
# > NUMBER OF CLIENT MACHINES: 706,330
#
#
# RUN 998 ===========================
# > MAX TRAFFIC: 5,306,880,613
# > START SERVER PLACEMENT AT INDEX: 148,891
# > END SERVER PLACEMENT ON INDEX: 697,869
# > NUMBER OF CLIENT MACHINES: 2,077,575
#
#
# RUN 999 ===========================
# > MAX TRAFFIC: 4,946,011,821
# > START SERVER PLACEMENT AT INDEX: 243,649
# > END SERVER PLACEMENT ON INDEX: 852,263
# > NUMBER OF CLIENT MACHINES: 1,110,036
#
#
# > RUNTIME (ns): [667326000, 657973000, 626466000, 597526000, 296940000, 222161000, 643217000, 361301000, 152517000, 454775000, 438551000, 409300000, 570594000, 374453000, 336330000, 264106000, 322301000, 489865000, 432646000, 268255000, 375248000, 415385000, 319328000, 629986000, 142994000, 539088000, 674329000, 211653000, 317910000, 566910000, 565745000, 322548000, 471510000, 155763000, 476564000, 649850000, 178335000, 101799000, 514648000, 625972000, 216125000, 513515000, 208845000, 118384000, 422360000, 384290000, 414481000, 331700000, 166217000, 461174000, 142699000, 37270000, 267206000, 38377000, 302283000, 528335000, 347180000, 563520000, 526427000, 251262000, 139381000, 521471000, 444759000, 178163000, 411493000, 207073000, 484389000, 43480000, 107722000, 445148000, 600935000, 553371000, 533415000, 372479000, 149701000, 676852000, 700613000, 379208000, 658705000, 416062000, 337988000, 241631000, 602037000, 81106000, 414957000, 480552000, 226964000, 53213000, 788348000, 135902000, 522656000, 681223000, 653541000, 649982000, 105297000, 233382000, 61953000, 468418000, 684690000, 469305000, 369004000, 652206000, 563087000, 509290000, 277745000, 585577000, 380121000, 1414857000, 448174000, 205016000, 952407000, 191762000, 92300000, 328631000, 284778000, 451679000, 357108000, 405357000, 615373000, 411673000, 133332000, 548997000, 247274000, 408682000, 385515000, 569275000, 249215000, 277654000, 661815000, 187075000, 460738000, 99379000, 63975000, 507245000, 723024000, 587106000, 202144000, 443867000, 472523000, 497218000, 539443000, 138254000, 593347000, 270320000, 728183000, 557248000, 138632000, 635961000, 657737000, 397461000, 465897000, 551513000, 380946000, 609307000, 591561000, 341899000, 235999000, 493098000, 533948000, 72385000, 280073000, 246538000, 494359000, 134035000, 380399000, 656012000, 514755000, 522012000, 607548000, 153969000, 472080000, 275069000, 139464000, 440247000, 218228000, 157586000, 472639000, 116623000, 244824000, 32569000, 372977000, 682631000, 263604000, 267987000, 504933000, 529198000, 424134000, 417925000, 145433000, 300263000, 410493000, 510110000, 165282000, 522322000, 431914000, 652820000, 141087000, 276102000, 475775000, 184140000, 22406000, 96649000, 250428000, 182155000, 26201000, 146177000, 602502000, 696848000, 662355000, 344974000, 172020000, 139425000, 420585000, 132020000, 114628000, 648367000, 743738000, 620928000, 590580000, 352468000, 440490000, 121777000, 547225000, 534633000, 646738000, 571917000, 706966000, 406173000, 634994000, 516874000, 185565000, 395360000, 639031000, 540646000, 673095000, 148000000, 55150000, 465838000, 400072000, 618918000, 317849000, 132568000, 134689000, 486583000, 327519000, 650175000, 266113000, 270959000, 566979000, 287521000, 580386000, 660892000, 726189000, 169989000, 211475000, 371293000, 177636000, 257367000, 550118000, 263018000, 269915000, 477613000, 169421000, 89406000, 49181000, 598802000, 257204000, 395916000, 293895000, 449111000, 667569000, 591479000, 140216000, 138798000, 535643000, 162140000, 123521000, 246007000, 396085000, 713273000, 362922000, 575600000, 229610000, 339306000, 304504000, 97170000, 78573000, 312924000, 635472000, 152024000, 55024000, 121997000, 812052000, 428018000, 165014000, 199628000, 62505000, 107060000, 607146000, 101655000, 299896000, 224238000, 225833000, 621573000, 473390000, 164490000, 100298000, 497399000, 187599000, 456103000, 614108000, 578422000, 562080000, 329499000, 312367000, 123034000, 379814000, 144094000, 85169000, 482087000, 296347000, 297365000, 315281000, 645077000, 640101000, 199182000, 689666000, 518320000, 467011000, 476898000, 355383000, 341550000, 537531000, 116471000, 21787000, 576334000, 554830000, 476281000, 590982000, 688683000, 147183000, 117678000, 42977000, 541851000, 569319000, 418891000, 511874000, 244790000, 152424000, 210697000, 370985000, 27013000, 257478000, 226766000, 80388000, 502107000, 83739000, 619104000, 551138000, 363068000, 69869000, 229219000, 194856000, 275169000, 973140 ...
# > ARRAY SIZE: [4733795, 4728475, 4610290, 4039756, 1618608, 1463973, 4673955, 2483655, 928526, 3629946, 3037567, 2991875, 3806467, 2068414, 2130024, 1664315, 2427992, 3674165, 3098571, 1875904, 2776173, 3132661, 2068073, 4499628, 912955, 4297917, 4892395, 714172, 2413020, 4100996, 3662299, 1817357, 3748853, 1142064, 3731521, 4854641, 1312344, 871082, 3950346, 4758238, 1339241, 4061272, 1286973, 941220, 3246501, 2574581, 2902876, 2137005, 1374860, 3630030, 902592, 304542, 2096820, 173519, 2429160, 4081652, 2416125, 4156564, 3438161, 1752673, 808064, 4158354, 3243385, 1360429, 3172626, 1246929, 3821497, 85139, 982793, 3446616, 4153501, 3595180, 3807318, 2586419, 1111664, 4555047, 4320839, 1885640, 4991526, 2347114, 2464845, 1773315, 4651303, 46216, 3153203, 3253108, 1210062, 410426, 4736987, 709882, 4231875, 4885212, 4580997, 4505454, 123140, 1065292, 463331, 3619809, 4773495, 3196897, 2340696, 4656145, 3794358, 2946134, 1547851, 4273603, 2432024, 4594744, 2697764, 1066198, 3445610, 1014678, 804879, 2456892, 1692520, 2942920, 2633693, 2474377, 4588615, 2757963, 1081114, 4314038, 1433048, 3179096, 2784437, 4446018, 1865971, 1981216, 4781098, 1185039, 3083129, 52566, 615884, 3841442, 4786658, 3504124, 633411, 3328876, 3221176, 3570347, 4030625, 571899, 4256922, 1847282, 4990066, 3713222, 94035, 4966760, 4661081, 2806521, 3449121, 4036777, 2520773, 4306275, 4573474, 1915961, 1440733, 3613870, 3683108, 21160, 2240810, 1682373, 3167503, 440551, 2816117, 4667992, 3401422, 3035928, 3682660, 853756, 3015657, 1701760, 932442, 3445606, 1515226, 891286, 3585593, 692698, 1983403, 183026, 2828008, 4658388, 1801919, 1872697, 3728423, 3482780, 3030433, 2839434, 590025, 2331426, 3111790, 3775082, 837309, 4037971, 2793279, 4721402, 525776, 2205869, 3503762, 955383, 170277, 849330, 1864488, 1092799, 194885, 1309968, 4565956, 4406367, 4221857, 1912818, 933832, 1213008, 3301303, 1065322, 987877, 4707452, 4912538, 4199728, 4456067, 2321913, 2939222, 525831, 4283115, 3729186, 4216109, 3822130, 4476170, 1925485, 4684605, 3502932, 917277, 3046683, 4711328, 3638649, 4316092, 690319, 461692, 3607562, 2606002, 4203278, 2300468, 1003216, 1184252, 3857670, 2350449, 4508716, 1350492, 1936592, 4233341, 1678577, 4471749, 4571917, 4714533, 691374, 1665661, 2772072, 999335, 1938521, 3939056, 1689279, 1916313, 3337364, 626714, 769484, 425050, 4729601, 1702442, 2917205, 1411998, 3319377, 4666176, 3747090, 293615, 1263454, 4102131, 1085090, 1123556, 1790132, 2724170, 4911084, 2021798, 4171935, 837228, 2596931, 2125205, 620614, 594334, 2415891, 4785649, 1195318, 465411, 1097919, 4109103, 2491480, 1203852, 1418785, 161970, 952110, 4405738, 523840, 2293220, 1443231, 1740172, 4756542, 3075098, 1158592, 821419, 3856305, 1379373, 3523875, 4537802, 3658463, 3408137, 2216693, 2050596, 964492, 2906814, 742592, 720827, 3593962, 1632399, 2054898, 1947274, 4670719, 4160161, 1040768, 2394350, 3315802, 1931592, 3669159, 2766147, 2601558, 4102276, 673994, 184505, 3838464, 3864914, 2797131, 4125653, 4851116, 425338, 1067517, 346111, 4205160, 4359911, 3005084, 3332446, 1765200, 948065, 1620547, 2702685, 6852, 2049086, 1605273, 247452, 3751533, 75836, 4856502, 3938009, 2574122, 6566, 1790103, 1206473, 2050493, 520525, 4036885, 4905558, 4847854, 3388503, 1912583, 1753747, 1373412, 2965252, 4011632, 2989253, 4158893, 919323, 2108164, 1598303, 2440266, 1120319, 3805438, 3062638, 3651288, 1779491, 767620, 306395, 2787370, 1141360, 1853693, 1226557, 4833053, 3831278, 4309915, 149299, 1617629, 2436712, 3979697, 2989753, 3293618, 4827645, 3469825, 4751646, 1764571, 3635731, 3905679, 2779893, 1928807, 4283119, 1014094, 2039542, 4587605, 4188332, 4165425, 4801660, 1365499, 4787904, 4366292, 1614024, 1649283, 1232012, 3918008, 600902, 3450161, 887739, 2313355, 68980, 1277292, 7670, 2553220, 1465105, 4238738, 2058007, 2769877, 2746411, 2228137, 250732, 1944268, 4145954, 4610544, 3446087, 1461329, 2343745, 3255235, 160568, 1674893, 1008881, 2174565, 2037280, 3918363, 4704167, 4765515, 2442084,  ...
